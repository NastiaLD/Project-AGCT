# %% [markdown]
# # Выбор способов иллюстрации графиков и их стиля с разными данными

# %% [markdown]
# Требования к иллюстрациям
# - Ссылка на используемые данные (таблицы)
#   - Причина: проверить расчёты и результат, воспроизводимость
# - Надпись с названием всей иллюстрации — `title`. Можно использовать LaTeX синтаксис внутри `'A \to B'` как $A \to B$, например.
#   - Причина: когда первый раз видишь график что бы его понять нужно осмысленное название, "что он показывает?".
# - Надпись у каждой из осей, переменная и её размерность
#   - Причина: когда нет названий осей график не понятен
# - Надпись в названием каждой линии или группы, обозначающей элементы иллюстрации в легенде
#   - Причина: должно быть понятно какая линия или элемент к какой группе данных, относится и однозначно отличать их друг от друга

# %% [markdown]
# ❗ Сделать такую иллюстрацию где сделаны визуальные сноски к каждому элементу графика

# %% [markdown]
# **Сравним способы создания иллюстраций между разными библиотеками (среднее количество загрузок в месяц в 2022 году): **
#
# | Название | Количество загрузок в месяц |
# |---|---|
# | `pandas` | 2 500 000 |
# | `matplotlib` | 800 000 |
# | `seaborn` | 280 000 |
# | `plotly` | 250 000 |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import numpy as np

# %% [markdown]
# ❗ Решение типичных проблем в том какие данные должны быть поданы на вход функции отрисовки что бы получить желаемый результат
